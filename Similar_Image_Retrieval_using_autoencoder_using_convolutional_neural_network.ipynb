# %% [markdown]
# <a href="https://colab.research.google.com/github/ArunadeviRamesh/Content-Based-Image-Retrieval-using-Autoencoders-Unsupervised-deep-learning-algorithms/blob/master/Similar_Image_Retrieval_using_autoencoder_using_convolutional_neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.neighbors import NearestNeighbors
from multiprocessing import Pool
from skimage.transform import resize
import os
import skimage.io
from multiprocessing import Pool
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from sklearn import manifold
import random

# %%
def __init__(self, modelName, info):
        self.modelName = modelName
        self.info = info
        self.autoencoder = None
        self.encoder = None
        self.decoder = None
def fit(self, X, n_epochs=50, batch_size=256):
        indices_fracs = split(fracs=[0.9, 0.1], N=len(X), seed=0)
        X_train, X_valid = X[indices_fracs[0]], X[indices_fracs[1]]
        self.autoencoder.fit(X_train, X_train,
                             epochs = n_epochs,
                             batch_size = batch_size,
                             shuffle = True,
                             validation_data = (X_valid, X_valid))
def predict(self, X):
        return self.encoder.predict(X)

# %%
def set_arch(self):

        shape_img = self.info["shape_img"]
        shape_img_flattened = (np.prod(list(shape_img)),)

        # Set encoder and decoder graphs
        if self.modelName == "simpleAE":
            encode_dim = 128

            input = tf.keras.Input(shape=shape_img_flattened)
            encoded = tf.keras.layers.Dense(encode_dim, activation='relu')(input)

            decoded = tf.keras.layers.Dense(shape_img_flattened[0], activation='sigmoid')(encoded)

        elif self.modelName == "convAE":
            n_hidden_1, n_hidden_2, n_hidden_3 = 16, 8, 8
            convkernel = (3, 3)  # convolution kernel
            poolkernel = (2, 2)  # pooling kernel

            input = tf.keras.layers.Input(shape=shape_img)
            x = tf.keras.layers.Conv2D(n_hidden_1, convkernel, activation='relu', padding='same')(input)
            x = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)
            x = tf.keras.layers.Conv2D(n_hidden_2, convkernel, activation='relu', padding='same')(x)
            x = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)
            x = tf.keras.layers.Conv2D(n_hidden_3, convkernel, activation='relu', padding='same')(x)
            encoded = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)

            x = tf.keras.layers.Conv2D(n_hidden_3, convkernel, activation='relu', padding='same')(encoded)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            x = tf.keras.layers.Conv2D(n_hidden_2, convkernel, activation='relu', padding='same')(x)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            x = tf.keras.layers.Conv2D(n_hidden_1, convkernel, activation='relu')(x)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            decoded = tf.keras.layers.Conv2D(shape_img[2], convkernel, activation='sigmoid', padding='same')(x)

        else:
            raise Exception("Invalid model name given!")

        # Create autoencoder model
        autoencoder = tf.keras.Model(input, decoded)
        input_autoencoder_shape = autoencoder.layers[0].input_shape[1:]
        output_autoencoder_shape = autoencoder.layers[-1].output_shape[1:]

        # Create encoder model
        encoder = tf.keras.Model(input, encoded)  # set encoder
        input_encoder_shape = encoder.layers[0].input_shape[1:]
        output_encoder_shape = encoder.layers[-1].output_shape[1:]

        # Create decoder model
        decoded_input = tf.keras.Input(shape=output_encoder_shape)
        if self.modelName == 'simpleAE':
            decoded_output = autoencoder.layers[-1](decoded_input)  # single layer
        elif self.modelName == 'convAE':
            decoded_output = autoencoder.layers[-7](decoded_input)  # Conv2D
            decoded_output = autoencoder.layers[-6](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-5](decoded_output)  # Conv2D
            decoded_output = autoencoder.layers[-4](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-3](decoded_output)  # Conv2D
            decoded_output = autoencoder.layers[-2](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-1](decoded_output)  # Conv2D
        else:
            raise Exception("Invalid model name given!")
        decoder = tf.keras.Model(decoded_input, decoded_output)
        decoder_input_shape = decoder.layers[0].input_shape[1:]
        decoder_output_shape = decoder.layers[-1].output_shape[1:]
        print("\nautoencoder.summary():")
        print(autoencoder.summary())
        print("\nencoder.summary():")
        print(encoder.summary())
        print("\ndecoder.summary():")
        print(decoder.summary())
        self.autoencoder = autoencoder
        self.encoder = encoder
        self.decoder = decoder

# %%
def compile(self, loss="binary_crossentropy", optimizer="adam"):
        self.autoencoder.compile(optimizer=optimizer, loss=acc)

# %%
def load_models(self, loss="binary_crossentropy", optimizer="adam"):
        print("Loading models...")
        self.autoencoder = tf.keras.models.load_model(self.info["autoencoderFile"])
        self.encoder = tf.keras.models.load_model(self.info["encoderFile"])
        self.decoder = tf.keras.models.load_model(self.info["decoderFile"])
        self.autoencoder.compile(optimizer=optimizer, loss=loss)
        self.encoder.compile(optimizer=optimizer, loss=loss)
        self.decoder.compile(optimizer=optimizer, loss=loss)

# %%
def save_models(self):
        print("Saving models...")
        self.autoencoder.save(self.info["autoencoderFile"])
        self.encoder.save(self.info["encoderFile"])
        self.decoder.save(self.info["decoderFile"])

# %%
def read_img(filePath):
    return skimage.io.imread(filePath, as_gray=False)

# %%
def read_imgs_dir(dirPath, extensions, parallel=True):
    args = [os.path.join(dirPath, filename)
            for filename in os.listdir(dirPath)
            if any(filename.lower().endswith(ext) for ext in extensions)]
    if parallel:
        pool = Pool()
        imgs = pool.map(read_img, args)
        pool.close()
        pool.join()
    else:
        imgs = [read_img(arg) for arg in args]
    return imgs

# %%
def save_img(filePath, img):
    skimage.io.imsave(filePath, img)

# %%
def plot_img(img, range=[0, 255]):
    plt.imshow(img, vmin=range[0], vmax=range[1])
    plt.xlabel("xpixels")
    plt.ylabel("ypixels")
    plt.tight_layout()
    plt.show()
    plt.close()

# %%
def plot_query_retrieval(img_query, imgs_retrieval, outFile):
    n_retrieval = len(imgs_retrieval)
    fig = plt.figure(figsize=(2*n_retrieval, 4))
    fig.suptitle("First kth similar Image Retrieval (k={})".format(n_retrieval), fontsize=15)

    # Plot query image
    ax = plt.subplot(2, n_retrieval, 0 + 1)
    plt.imshow(img_query)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    for axis in ['top', 'bottom', 'left', 'right']:
        ax.spines[axis].set_linewidth(4)  # increase border thickness
        ax.spines[axis].set_color('black')  # set to black
    ax.set_title("query",  fontsize=8)  # set subplot title

    # Plot retrieval images
    for i, img in enumerate(imgs_retrieval):
        ax = plt.subplot(2, n_retrieval, n_retrieval + i + 1)
        plt.imshow(img)
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        for axis in ['top', 'bottom', 'left', 'right']:
            ax.spines[axis].set_linewidth(1)  # set border thickness
            ax.spines[axis].set_color('black')  # set to black
        ax.set_title("%d same images" % (i+1), fontsize=14)  # set subplot title

    if outFile is None:
        plt.show()
    else:
        plt.savefig(outFile, bbox_inches='tight')
    plt.close()

# %%
def plot_tsne(X, imgs, outFile):

    def imscatter(x, y, images, ax=None, zoom=1.0):
        if ax is None:
            ax = plt.gca()
        x, y = np.atleast_1d(x, y)
        artists = []
        for x0, y0, img0 in zip(x, y, images):
            im = OffsetImage(img0, zoom=zoom)
            ab = AnnotationBbox(im, (x0, y0), xycoords='data', frameon=True)
            artists.append(ax.add_artist(ab))
        ax.update_datalim(np.column_stack([x, y]))
        ax.autoscale()
        return artists

    def plot_embedding(X, imgs, title=None):
        x_min, x_max = np.min(X, 0), np.max(X, 0)
        X = (X - x_min) / (x_max - x_min)

        plt.figure()
        ax = plt.subplot(111)
        for i in range(X.shape[0]):
            plt.text(X[i, 0], X[i, 1], ".", fontdict={'weight': 'bold', 'size': 9})
        if hasattr(offsetbox, 'AnnotationBbox'):
            imscatter(X[:,0], X[:,1], imgs, zoom=0.3, ax=ax)

        plt.xticks([]), plt.yticks([])
        if title is not None:
            plt.title(title, fontsize=18)

    tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
    X_tsne = tsne.fit_transform(X)
    plot_embedding(X_tsne, imgs, "t-SNE embeddings")
    if outFile is None:
        plt.show()
    else:
        plt.savefig(outFile, bbox_inches='tight')
    plt.close()

# Plot image reconstructions

# %%
def plot_reconstructions(imgs, imgs_reconstruct, outFile,
                         range_imgs=[0, 255],
                         range_imgs_reconstruct=[0, 1]):
    # Create plot to save
    assert len(imgs) == len(imgs_reconstruct)
    fig = plt.figure(figsize=(20, 4))
    fig.suptitle("Image Reconstructions", fontsize=35)
    n = min(len(imgs), 10)
    for i in range(n):

        # Plot original image
        ax = plt.subplot(2, n, i + 1)
        plt.imshow(imgs[i],
                   vmin=range_imgs[0],
                   vmax=range_imgs[1])
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

        # Plot reconstructed image
        ax = plt.subplot(2, n, n + i + 1)
        plt.imshow(imgs_reconstruct[i],
                   vmin=range_imgs_reconstruct[0],
                   vmax=range_imgs_reconstruct[1])
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

    if outFile is None:
        plt.show()
    else:
        plt.savefig(outFile, bbox_inches='tight')
    plt.close()

# %%
def apply_transformer(imgs, transformer, parallel=True):
    if parallel:
        pool = Pool()
        imgs_transform = pool.map(transformer, [img for img in imgs])
        pool.close()
        pool.join()
    else:
        imgs_transform = [transformer(img) for img in imgs]
    return imgs_transform

# %%
def normalize_img(img):
    return img / 255.

# %%
def resize_img(img, shape_resized):
    img_resized = resize(img, shape_resized,
                         anti_aliasing=True,
                         preserve_range=True)
    assert img_resized.shape == shape_resized
    return img_resized

# %%
def flatten_img(img):
    return img.flatten("C")

# %%
def split(fracs, N, seed):
    fracs = [round(frac, 2) for frac in fracs]
    if sum(fracs) != 1.00:
        raise Exception("fracs do not sum to one!")

    # Shuffle ordered indices
    indices = list(range(N))
    random.Random(seed).shuffle(indices)
    indices = np.array(indices, dtype=int)

    # Get numbers per group
    n_fracs = []
    for i in range(len(fracs) - 1):
        n_fracs.append(int(max(fracs[i] * N, 0)))
    n_fracs.append(int(max(N - sum(n_fracs), 0)))

    if sum(n_fracs) != N:
        raise Exception("n_fracs do not sum to N!")

    # Sample indices
    n_selected = 0
    indices_fracs = []
    for n_frac in n_fracs:
        indices_frac = indices[n_selected:n_selected + n_frac]
        indices_fracs.append(indices_frac)
        n_selected += n_frac

    # Check no intersections
    for a, indices_frac_A in enumerate(indices_fracs):
        for b, indices_frac_B in enumerate(indices_fracs):
            if a == b:
                continue
            if is_intersect(indices_frac_A, indices_frac_B):
                raise Exception("there are intersections!")

    return indices_fracs

# %%
def is_intersect(arr1, arr2):
    n_intersect = len(np.intersect1d(arr1, arr2))
    if n_intersect == 0: return False
    else: return True

# %%
modelName = "convAE"  # try: "simpleAE", "convAE", "vgg19"
trainModel = True
parallel = True  # use multicore processing
dataTrainDir = "/content/drive/My Drive/Machine Learning/Image retrieval dataset/train"
dataTestDir = "/content/drive/My Drive/Machine Learning/Image retrieval dataset/test"

# %%
outDir = "/content/drive/My Drive/Machine Learning/Output images"
if not os.path.exists(outDir):
    os.makedirs(outDir)

# %%
extensions = [".jpg", ".jpeg"]
print("Reading train 1 images from '{}'...".format(dataTrainDir))
imgs_train = read_imgs_dir(dataTrainDir, extensions, parallel=parallel)
print("Reading test images from '{}'...".format(dataTestDir))
imgs_test = read_imgs_dir(dataTestDir, extensions, parallel=parallel)
shape_img = imgs_test[1].shape
print("Image shape = {}".format(shape_img))
# Out:
# Reading train 1 images from '/content/drive/My Drive/Machine Learning/Image retrieval dataset/train'...
# Reading test images from '/content/drive/My Drive/Machine Learning/Image retrieval dataset/test'...
# Image shape = (100, 100, 3)

# %%
class AutoEncoder():
    def __init__(self, modelName, info):
        self.modelName = modelName
        self.info = info
        self.autoencoder = None
        self.encoder = None
        self.decoder = None
    def fit(self, X, n_epochs=500, batch_size=256):
        indices_fracs = split(fracs=[0.9, 0.1], N=len(X), seed=0)
        X_train, X_valid = X[indices_fracs[0]], X[indices_fracs[1]]
        self.autoencoder.fit(X_train, X_train,
                             epochs = n_epochs,
                             batch_size = batch_size,
                             shuffle = True,
                             validation_data = (X_valid, X_valid))

    # Inference
    def predict(self, X):
        return self.encoder.predict(X)

    # Set neural network architecture
    def set_arch(self):

        shape_img = self.info["shape_img"]
        shape_img_flattened = (np.prod(list(shape_img)),)

        # Set encoder and decoder graphs
        if self.modelName == "simpleAE":
            encode_dim = 128

            input = tf.keras.Input(shape=shape_img_flattened)
            encoded = tf.keras.layers.Dense(encode_dim, activation='relu')(input)

            decoded = tf.keras.layers.Dense(shape_img_flattened[0], activation='sigmoid')(encoded)

        elif self.modelName == "convAE":
            n_hidden_1, n_hidden_2, n_hidden_3 = 16, 8, 8
            convkernel = (3, 3)  # convolution kernel
            poolkernel = (2, 2)  # pooling kernel

            input = tf.keras.layers.Input(shape=shape_img)
            x = tf.keras.layers.Conv2D(n_hidden_1, convkernel, activation='relu', padding='same')(input)
            x = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)
            x = tf.keras.layers.Conv2D(n_hidden_2, convkernel, activation='relu', padding='same')(x)
            x = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)
            x = tf.keras.layers.Conv2D(n_hidden_3, convkernel, activation='relu', padding='same')(x)
            encoded = tf.keras.layers.MaxPooling2D(poolkernel, padding='same')(x)

            x = tf.keras.layers.Conv2D(n_hidden_3, convkernel, activation='relu', padding='same')(encoded)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            x = tf.keras.layers.Conv2D(n_hidden_2, convkernel, activation='relu', padding='same')(x)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            x = tf.keras.layers.Conv2D(n_hidden_1, convkernel, activation='relu')(x)
            x = tf.keras.layers.UpSampling2D(poolkernel)(x)
            decoded = tf.keras.layers.Conv2D(shape_img[2], convkernel, activation='sigmoid', padding='same')(x)

        else:
            raise Exception("Invalid model name given!")

        # Create autoencoder model
        autoencoder = tf.keras.Model(input, decoded)
        input_autoencoder_shape = autoencoder.layers[0].input_shape[1:]
        output_autoencoder_shape = autoencoder.layers[-1].output_shape[1:]

        # Create encoder model
        encoder = tf.keras.Model(input, encoded)  # set encoder
        input_encoder_shape = encoder.layers[0].input_shape[1:]
        output_encoder_shape = encoder.layers[-1].output_shape[1:]

        # Create decoder model
        decoded_input = tf.keras.Input(shape=output_encoder_shape)
        if self.modelName == 'simpleAE':
            decoded_output = autoencoder.layers[-1](decoded_input)  # single layer
        elif self.modelName == 'convAE':
            decoded_output = autoencoder.layers[-7](decoded_input)  # Conv2D
            decoded_output = autoencoder.layers[-6](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-5](decoded_output)  # Conv2D
            decoded_output = autoencoder.layers[-4](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-3](decoded_output)  # Conv2D
            decoded_output = autoencoder.layers[-2](decoded_output)  # UpSampling2D
            decoded_output = autoencoder.layers[-1](decoded_output)  # Conv2D
        else:
            raise Exception("Invalid model name given!")
        decoder = tf.keras.Model(decoded_input, decoded_output)
        decoder_input_shape = decoder.layers[0].input_shape[1:]
        decoder_output_shape = decoder.layers[-1].output_shape[1:]

        # Generate summaries
        print("\nautoencoder.summary():")
        print(autoencoder.summary())
        print("\nencoder.summary():")
        print(encoder.summary())
        print("\ndecoder.summary():")
        print(decoder.summary())

        # Assign models
        self.autoencoder = autoencoder
        self.encoder = encoder
        self.decoder = decoder

    # Compile
    def compile(self, loss="binary_crossentropy", optimizer="adam"):
        self.autoencoder.compile(optimizer=optimizer, loss=loss)

    # Load model architecture and weights
    def load_models(self, loss="binary_crossentropy", optimizer="adam"):
        print("Loading models...")
        self.autoencoder = tf.keras.models.load_model(self.info["autoencoderFile"])
        self.encoder = tf.keras.models.load_model(self.info["encoderFile"])
        self.decoder = tf.keras.models.load_model(self.info["decoderFile"])
        self.autoencoder.compile(optimizer=optimizer, loss=loss)
        self.encoder.compile(optimizer=optimizer, loss=loss)
        self.decoder.compile(optimizer=optimizer, loss=loss)

    # Save model architecture and weights to file
    def save_models(self):
        print("Saving models...")
        self.autoencoder.save(self.info["autoencoderFile"])
        self.encoder.save(self.info["encoderFile"])
        self.decoder.save(self.info["decoderFile"])

# %%
if modelName in ["simpleAE", "convAE"]:

    # Set up autoencoder
    info = {
        "shape_img": shape_img,
        "autoencoderFile": os.path.join(outDir, "{}_autoecoder.h5".format(modelName)),
        "encoderFile": os.path.join(outDir, "{}_encoder.h5".format(modelName)),
        "decoderFile": os.path.join(outDir, "{}_decoder.h5".format(modelName)),
    }
    model = AutoEncoder(modelName, info)
    model.set_arch()

    if modelName == "simpleAE":
        shape_img_resize = shape_img
        input_shape_model = (model.encoder.input.shape[1],)
        output_shape_model = (model.encoder.output.shape[1],)
        n_epochs = 300
    elif modelName == "convAE":
        shape_img_resize = shape_img
        input_shape_model = tuple([int(x) for x in model.encoder.input.shape[1:]])
        output_shape_model = tuple([int(x) for x in model.encoder.output.shape[1:]])
        n_epochs = 500
    else:
        raise Exception("Invalid modelName!")

elif modelName in ["vgg19"]:

    # Load pre-trained VGG19 model + higher level layers
    print("Loading VGG19 pre-trained model...")
    model = tf.keras.applications.VGG19(weights='imagenet', include_top=False,
                                        input_shape=shape_img)
    model.summary()

    shape_img_resize = tuple([int(x) for x in model.input.shape[1:]])
    input_shape_model = tuple([int(x) for x in model.input.shape[1:]])
    output_shape_model = tuple([int(x) for x in model.output.shape[1:]])
    n_epochs = None

else:
    raise Exception("Invalid modelName!")

# Print some model info
print("input_shape_model = {}".format(input_shape_model))
print("output_shape_model = {}".format(output_shape_model))
# Out:
# autoencoder.summary():
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 8)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 100, 100, 3)       435
# =================================================================
# Total params: 4,963
# Trainable params: 4,963
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# encoder.summary():
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 100, 100, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 100, 100, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 8)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 8)         584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 8)         0
# =================================================================
# Total params: 2,192
# Trainable params: 2,192
# Non-trainable params: 0
# _________________________________________________________________
# None
#
# decoder.summary():
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 13, 13, 8)]       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 8)         584
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 26, 26, 8)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 26, 26, 8)         584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 52, 52, 8)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 50, 50, 16)        1168
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 100, 100, 16)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 100, 100, 3)       435
# =================================================================
# Total params: 2,771
# Trainable params: 2,771
# Non-trainable params: 0
# _________________________________________________________________
# None
# input_shape_model = (100, 100, 3)
# output_shape_model = (13, 13, 8)

# %%
class ImageTransformer(object):

    def __init__(self, shape_resize):
        self.shape_resize = shape_resize

    def __call__(self, img):
        img_transformed = resize_img(img, self.shape_resize)
        img_transformed = normalize_img(img_transformed)
        return img_transformed

# %%
transformer = ImageTransformer(shape_img_resize)
print("Applying image transformer to training images 1...")
imgs_train_transformed = apply_transformer(imgs_train, transformer, parallel=parallel)
# Out:
# Applying image transformer to training images 1...

# %%
print("Applying image transformer to test images...")
imgs_test_transformed = apply_transformer(imgs_test, transformer, parallel=parallel)
# Convert images to numpy array
# Out:
# Applying image transformer to test images...

# %%
X_train = np.array(imgs_train_transformed).reshape((-1,) + input_shape_model)

# %%
X_test = np.array(imgs_test_transformed).reshape((-1,) + input_shape_model)
print(" X_train.shape = {}".format(X_train.shape))
print("X_test.shape = {}".format(X_test.shape))
# Out:
#  X_train.shape = (48, 100, 100, 3)
# X_test.shape = (10, 100, 100, 3)

# %%
if modelName in ["simpleAE", "convAE"]:
    if trainModel:
        model.compile(loss="binary_crossentropy", optimizer="adam")
        model.fit(X_train, n_epochs=500, batch_size=256)
        model.save_models()
    else:
        model.load_models(loss="binary_crossentropy", optimizer="adam")
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 244ms/step - loss: 0.6923 - val_loss: 0.6884
# Epoch 2/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.6895 - val_loss: 0.6833
# Epoch 3/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6852 - val_loss: 0.6765
# Epoch 4/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6796 - val_loss: 0.6679
# Epoch 5/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6726 - val_loss: 0.6577
# Epoch 6/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6644 - val_loss: 0.6454
# Epoch 7/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.6547 - val_loss: 0.6312
# Epoch 8/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.6437 - val_loss: 0.6160
# Epoch 9/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6322 - val_loss: 0.6017
# Epoch 10/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6224 - val_loss: 0.5924
# Epoch 11/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6180 - val_loss: 0.5893
# Epoch 12/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6191 - val_loss: 0.5891
# Epoch 13/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6214 - val_loss: 0.5873
# Epoch 14/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.6204 - val_loss: 0.5841
# Epoch 15/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6169 - val_loss: 0.5811
# Epoch 16/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.6127 - val_loss: 0.5794
# Epoch 17/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6095 - val_loss: 0.5785
# Epoch 18/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6074 - val_loss: 0.5779
# Epoch 19/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6061 - val_loss: 0.5773
# Epoch 20/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.6051 - val_loss: 0.5762
# Epoch 21/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.6040 - val_loss: 0.5742
# Epoch 22/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.6026 - val_loss: 0.5709
# Epoch 23/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.6005 - val_loss: 0.5665
# Epoch 24/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5980 - val_loss: 0.5609
# Epoch 25/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5953 - val_loss: 0.5554
# Epoch 26/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.5936 - val_loss: 0.5522
# Epoch 27/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.5935 - val_loss: 0.5495
# Epoch 28/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5923 - val_loss: 0.5466
# Epoch 29/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.5893 - val_loss: 0.5447
# Epoch 30/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.5865 - val_loss: 0.5440
# Epoch 31/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5846 - val_loss: 0.5431
# Epoch 32/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5831 - val_loss: 0.5405
# Epoch 33/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5811 - val_loss: 0.5354
# Epoch 34/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.5779 - val_loss: 0.5284
# Epoch 35/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.5740 - val_loss: 0.5214
# Epoch 36/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5707 - val_loss: 0.5155
# Epoch 37/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5679 - val_loss: 0.5096
# Epoch 38/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.5630 - val_loss: 0.5047
# Epoch 39/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.5578 - val_loss: 0.5005
# Epoch 40/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5537 - val_loss: 0.4937
# Epoch 41/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.5491 - val_loss: 0.4854
# Epoch 42/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.
500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4281 - val_loss: 0.3684
# Epoch 171/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4280 - val_loss: 0.3690
# Epoch 172/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4278 - val_loss: 0.3682
# Epoch 173/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4277 - val_loss: 0.3687
# Epoch 174/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4276 - val_loss: 0.3680
# Epoch 175/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4275 - val_loss: 0.3683
# Epoch 176/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4274 - val_loss: 0.3677
# Epoch 177/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4272 - val_loss: 0.3680
# Epoch 178/500
# 1/1 [==============================] - 0s 83ms/step - loss: 0.4271 - val_loss: 0.3677
# Epoch 179/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4270 - val_loss: 0.3679
# Epoch 180/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4269 - val_loss: 0.3674
# Epoch 181/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4268 - val_loss: 0.3677
# Epoch 182/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4267 - val_loss: 0.3669
# Epoch 183/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4267 - val_loss: 0.3678
# Epoch 184/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4266 - val_loss: 0.3664
# Epoch 185/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4266 - val_loss: 0.3688
# Epoch 186/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4267 - val_loss: 0.3658
# Epoch 187/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.4269 - val_loss: 0.3709
# Epoch 188/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4275 - val_loss: 0.3657
# Epoch 189/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4277 - val_loss: 0.3714
# Epoch 190/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4276 - val_loss: 0.3656
# Epoch 191/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4264 - val_loss: 0.3662
# Epoch 192/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4260 - val_loss: 0.3690
# Epoch 193/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4264 - val_loss: 0.3654
# Epoch 194/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4263 - val_loss: 0.3670
# Epoch 195/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4258 - val_loss: 0.3672
# Epoch 196/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4257 - val_loss: 0.3649
# Epoch 197/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4260 - val_loss: 0.3679
# Epoch 198/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4259 - val_loss: 0.3652
# Epoch 199/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4255 - val_loss: 0.3651
# Epoch 200/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4254 - val_loss: 0.3675
# Epoch 201/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4256 - val_loss: 0.3646
# Epoch 202/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4256 - val_loss: 0.3662
# Epoch 203/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4252 - val_loss: 0.3656
# Epoch 204/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4251 - val_loss: 0.3644
# Epoch 205/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4252 - val_loss: 0.3666
# Epoch 206/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4252 - val_loss: 0.3645
# Epoch 207/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4250 - val_loss: 0.3649
# Epoch 208/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4248 - val_loss: 0.3658
# Epoch 209/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4249 - val_loss: 0.3640
# Epoch 210/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4249 - val_loss: 0.3655
# Epoch 211/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.4247 - val_loss: 0.3646
# Epoch 212/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4246 - val_loss: 0.3640
# Epoch 213/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4246 - val_loss: 0.3655
# Epoch 214/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4246 - val_loss: 0.3637
# Epoch 215/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4245 - val_loss: 0.3645
# Epoch 216/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.4244 - val_loss: 0.3646
# Epoch 217/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4243 - val_loss: 0.3636
# Epoch 218/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4243 - val_loss: 0.3648
# Epoch 219/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4243 - val_loss: 0.3636
# Epoch 220/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.4242 - val_loss: 0.3637
# Epoch 221/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4241 - val_loss: 0.3640
# Epoch 222/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4241 - val_loss: 0.3634
# Epoch 223/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4240 - val_loss: 0.3641
# Epoch 224/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4240 - val_loss: 0.3636
# Epoch 225/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4239 - val_loss: 0.3634
# Epoch 226/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4239 - val_loss: 0.3638
# Epoch 227/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4238 - val_loss: 0.3630
# Epoch 228/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4238 - val_loss: 0.3637
# Epoch 229/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4237 - val_loss: 0.3632
# Epoch 230/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4237 - val_loss: 0.3630
# Epoch 231/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4236 - val_loss: 0.3634
# Epoch 232/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4236 - val_loss: 0.3628
# Epoch 233/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4236 - val_loss: 0.3634
# Epoch 234/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4235 - val_loss: 0.3630
# Epoch 235/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.4234 - val_loss: 0.3628
# Epoch 236/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4234 - val_loss: 0.3629
# Epoch 237/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4234 - val_loss: 0.3625
# Epoch 238/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4233 - val_loss: 0.3630
# Epoch 239/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4233 - val_loss: 0.3626
# Epoch 240/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4232 - val_loss: 0.3626
# Epoch 241/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4232 - val_loss: 0.3626
# Epoch 242/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4231 - val_loss: 0.3623
# Epoch 243/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4231 - val_loss: 0.3627
# Epoch 244/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4231 - val_loss: 0.3623
# Epoch 245/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4230 - val_loss: 0.3625
# Epoch 246/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4230 - val_loss: 0.3622
# Epoch 247/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4229 - val_loss: 0.3622
# Epoch 248/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.4229 - val_loss: 0.3621
# Epoch 249/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4229 - val_loss: 0.3621
# Epoch 250/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4228 - val_loss: 0.3620
# Epoch 251/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4228 - val_loss: 0.3621
# Epoch 252/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4228 - val_loss: 0.3621
# Epoch 253/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4227 - val_loss: 0.3618
# Epoch 254/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4227 - val_loss: 0.3618
# Epoch 255/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4226 - val_loss: 0.3617
# Epoch 256/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4226 - val_loss: 0.3619
# Epoch 257/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4226 - val_loss: 0.3617
# Epoch 258/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4225 - val_loss: 0.3616
# Epoch 259/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4225 - val_loss: 0.3614
# Epoch 260/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4224 - val_loss: 0.3616
# Epoch 261/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4224 - val_loss: 0.3614
# Epoch 262/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4224 - val_loss: 0.3616
# Epoch 263/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4223 - val_loss: 0.3611
# Epoch 264/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4223 - val_loss: 0.3616
# Epoch 265/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4223 - val_loss: 0.3609
# Epoch 266/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4223 - val_loss: 0.3617
# Epoch 267/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4222 - val_loss: 0.3607
# Epoch 268/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4222 - val_loss: 0.3616
# Epoch 269/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.4222 - val_loss: 0.3605
# Epoch 270/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4222 - val_loss: 0.3615
# Epoch 271/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4221 - val_loss: 0.3604
# Epoch 272/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4221 - val_loss: 0.3618
# Epoch 273/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4221 - val_loss: 0.3603
# Epoch 274/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4221 - val_loss: 0.3622
# Epoch 275/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4222 - val_loss: 0.3601
# Epoch 276/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4221 - val_loss: 0.3624
# Epoch 277/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4222 - val_loss: 0.3601
# Epoch 278/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4221 - val_loss: 0.3614
# Epoch 279/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4219 - val_loss: 0.3605
# Epoch 280/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4218 - val_loss: 0.3601
# Epoch 281/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4218 - val_loss: 0.3617
# Epoch 282/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4219 - val_loss: 0.3597
# Epoch 283/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4221 - val_loss: 0.3631
# Epoch 284/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4223 - val_loss: 0.3596
# Epoch 285/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4223 - val_loss: 0.3629
# Epoch 286/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4222 - val_loss: 0.3596
# Epoch 287/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4219 - val_loss: 0.3608
# Epoch 288/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4216 - val_loss: 0.3603
# Epoch 289/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4215 - val_loss: 0.3594
# Epoch 290/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4216 - val_loss: 0.3620
# Epoch 291/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4218 - val_loss: 0.3594
# Epoch 292/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.4218 - val_loss: 0.3613
# Epoch 293/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4215 - val_loss: 0.3597
# Epoch 294/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4213 - val_loss: 0.3595
# Epoch 295/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4213 - val_loss: 0.3614
# Epoch 296/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4215 - val_loss: 0.3591
# Epoch 297/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4216 - val_loss: 0.3615
# Epoch 298/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4215 - val_loss: 0.3591
# Epoch 299/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4213 - val_loss: 0.3598
# Epoch 300/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4211 - val_loss: 0.3601
# Epoch 301/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4211 - val_loss: 0.3590
# Epoch 302/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4213 - val_loss: 0.3612
# Epoch 303/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4214 - val_loss: 0.3590
# Epoch 304/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4212 - val_loss: 0.3600
# Epoch 305/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4210 - val_loss: 0.3594
# Epoch 306/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4210 - val_loss: 0.3589
# Epoch 307/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4210 - val_loss: 0.3607
# Epoch 308/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4211 - val_loss: 0.3588
# Epoch 309/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4211 - val_loss: 0.3607
# Epoch 310/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4211 - val_loss: 0.3588
# Epoch 311/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4209 - val_loss: 0.3595
# Epoch 312/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4208 - val_loss: 0.3595
# Epoch 313/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4208 - val_loss: 0.3588
# Epoch 314/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4208 - val_loss: 0.3600
# Epoch 315/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4208 - val_loss: 0.3585
# Epoch 316/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4208 - val_loss: 0.3594
# Epoch 317/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4207 - val_loss: 0.3588
# Epoch 318/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4206 - val_loss: 0.3592
# Epoch 319/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4206 - val_loss: 0.3592
# Epoch 320/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.4206 - val_loss: 0.3587
# Epoch 321/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4206 - val_loss: 0.3594
# Epoch 322/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4206 - val_loss: 0.3584
# Epoch 323/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4206 - val_loss: 0.3596
# Epoch 324/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.4205 - val_loss: 0.3583
# Epoch 325/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4205 - val_loss: 0.3592
# Epoch 326/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4205 - val_loss: 0.3584
# Epoch 327/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4204 - val_loss: 0.3591
# Epoch 328/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4204 - val_loss: 0.3585
# Epoch 329/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4203 - val_loss: 0.3586
# Epoch 330/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.4203 - val_loss: 0.3586
# Epoch 331/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4203 - val_loss: 0.3582
# Epoch 332/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4202 - val_loss: 0.3589
# Epoch 333/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4202 - val_loss: 0.3580
# Epoch 334/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4203 - val_loss: 0.3596
# Epoch 335/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4203 - val_loss: 0.3576
# Epoch 336/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.4204 - val_loss: 0.3602
# Epoch 337/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4205 - val_loss: 0.3575
# Epoch 338/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4206 - val_loss: 0.3607
# Epoch 339/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4206 - val_loss: 0.3576
# Epoch 340/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4204 - val_loss: 0.3592
# Epoch 341/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4202 - val_loss: 0.3579
# Epoch 342/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4200 - val_loss: 0.3579
# Epoch 343/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4200 - val_loss: 0.3591
# Epoch 344/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4201 - val_loss: 0.3573
# Epoch 345/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4202 - val_loss: 0.3600
# Epoch 346/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4204 - val_loss: 0.3573
# Epoch 347/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4205 - val_loss: 0.3613
# Epoch 348/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4207 - val_loss: 0.3574
# Epoch 349/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4206 - val_loss: 0.3605
# Epoch 350/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4204 - val_loss: 0.3572
# Epoch 351/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4200 - val_loss: 0.3585
# Epoch 352/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4198 - val_loss: 0.3582
# Epoch 353/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4198 - val_loss: 0.3572
# Epoch 354/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4199 - val_loss: 0.3593
# Epoch 355/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4200 - val_loss: 0.3571
# Epoch 356/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4199 - val_loss: 0.3588
# Epoch 357/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4198 - val_loss: 0.3574
# Epoch 358/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.4197 - val_loss: 0.3577
# Epoch 359/500
# 1/1 [==============================] - 0s 340ms/step - loss: 0.4196 - val_loss: 0.3584
# Epoch 360/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.
500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.4186 - val_loss: 0.3570
# Epoch 426/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4185 - val_loss: 0.3556
# Epoch 427/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4184 - val_loss: 0.3564
# Epoch 428/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4184 - val_loss: 0.3556
# Epoch 429/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.4183 - val_loss: 0.3559
# Epoch 430/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4183 - val_loss: 0.3557
# Epoch 431/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4183 - val_loss: 0.3560
# Epoch 432/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4183 - val_loss: 0.3557
# Epoch 433/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4183 - val_loss: 0.3558
# Epoch 434/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.4182 - val_loss: 0.3555
# Epoch 435/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4182 - val_loss: 0.3560
# Epoch 436/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4182 - val_loss: 0.3554
# Epoch 437/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4182 - val_loss: 0.3562
# Epoch 438/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4182 - val_loss: 0.3552
# Epoch 439/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4183 - val_loss: 0.3566
# Epoch 440/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4183 - val_loss: 0.3550
# Epoch 441/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.4184 - val_loss: 0.3573
# Epoch 442/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4185 - val_loss: 0.3549
# Epoch 443/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4186 - val_loss: 0.3579
# Epoch 444/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4187 - val_loss: 0.3549
# Epoch 445/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4185 - val_loss: 0.3572
# Epoch 446/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4184 - val_loss: 0.3554
# Epoch 447/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4182 - val_loss: 0.3556
# Epoch 448/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4181 - val_loss: 0.3566
# Epoch 449/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4182 - val_loss: 0.3548
# Epoch 450/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4183 - val_loss: 0.3575
# Epoch 451/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4185 - val_loss: 0.3547
# Epoch 452/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.4185 - val_loss: 0.3578
# Epoch 453/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.4185 - val_loss: 0.3548
# Epoch 454/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4183 - val_loss: 0.3571
# Epoch 455/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4182 - val_loss: 0.3553
# Epoch 456/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4180 - val_loss: 0.3554
# Epoch 457/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4180 - val_loss: 0.3564
# Epoch 458/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4181 - val_loss: 0.3549
# Epoch 459/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4181 - val_loss: 0.3566
# Epoch 460/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4181 - val_loss: 0.3546
# Epoch 461/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4180 - val_loss: 0.3562
# Epoch 462/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4180 - val_loss: 0.3547
# Epoch 463/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4180 - val_loss: 0.3560
# Epoch 464/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4179 - val_loss: 0.3546
# Epoch 465/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.4179 - val_loss: 0.3561
# Epoch 466/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4179 - val_loss: 0.3546
# Epoch 467/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4179 - val_loss: 0.3558
# Epoch 468/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4179 - val_loss: 0.3545
# Epoch 469/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4179 - val_loss: 0.3560
# Epoch 470/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4179 - val_loss: 0.3545
# Epoch 471/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4179 - val_loss: 0.3564
# Epoch 472/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.4179 - val_loss: 0.3545
# Epoch 473/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4179 - val_loss: 0.3561
# Epoch 474/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4178 - val_loss: 0.3546
# Epoch 475/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4177 - val_loss: 0.3552
# Epoch 476/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4177 - val_loss: 0.3547
# Epoch 477/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4176 - val_loss: 0.3546
# Epoch 478/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4176 - val_loss: 0.3551
# Epoch 479/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4176 - val_loss: 0.3544
# Epoch 480/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4177 - val_loss: 0.3556
# Epoch 481/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4177 - val_loss: 0.3541
# Epoch 482/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.4178 - val_loss: 0.3572
# Epoch 483/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4181 - val_loss: 0.3543
# Epoch 484/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4186 - val_loss: 0.3605
# Epoch 485/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.4195 - val_loss: 0.3551
# Epoch 486/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4196 - val_loss: 0.3612
# Epoch 487/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4195 - val_loss: 0.3550
# Epoch 488/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4180 - val_loss: 0.3548
# Epoch 489/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.4178 - val_loss: 0.3585
# Epoch 490/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.4188 - val_loss: 0.3549
# Epoch 491/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.4185 - val_loss: 0.3566
# Epoch 492/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.4177 - val_loss: 0.3565
# Epoch 493/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4179 - val_loss: 0.3545
# Epoch 494/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4184 - val_loss: 0.3578
# Epoch 495/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4181 - val_loss: 0.3557
# Epoch 496/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.4176 - val_loss: 0.3548
# Epoch 497/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4178 - val_loss: 0.3574
# Epoch 498/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.4181 - val_loss: 0.3543
# Epoch 499/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.4177 - val_loss: 0.3549
# Epoch 500/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4175 - val_loss: 0.3563
# Saving models...

# %%
print("Inferencing embeddings using pre-trained model...")
E_train = model.predict(X_train)
E_train_flatten = E_train.reshape((-1, np.prod(output_shape_model)))
# Out:
# Inferencing embeddings using pre-trained model...

# %%
E_test = model.predict(X_test)
E_test_flatten = E_test.reshape((-1, np.prod(output_shape_model)))

# %%
print(" E_train.shape = {}".format(E_train.shape))
print(" E_test.shape = {}".format(E_test.shape))
print(" E_train_flatten.shape = {}".format(E_train_flatten.shape))
print(" E_test_flatten.shape = {}".format(E_test_flatten.shape))
# Out:
#  E_train.shape = (48, 13, 13, 8)
#  E_test.shape = (10, 13, 13, 8)
#  E_train_flatten.shape = (48, 1352)
#  E_test_flatten.shape = (10, 1352)

# %%
if modelName in ["simpleAE", "convAE"]:
    print("Visualizing database image reconstructions...")
    imgs_train_reconstruct = model.decoder.predict(E_train)
    if modelName == "simpleAE":
        imgs_train_reconstruct = imgs_train_reconstruct.reshape((-1,) + shape_img_resize)
    plot_reconstructions(imgs_train, imgs_train_reconstruct,
                         os.path.join(outDir, "{}_reconstruct.png".format(modelName)),
                         range_imgs=[0, 255],
                         range_imgs_reconstruct=[0, 1])
# Out:
# Visualizing database image reconstructions...

# %%
print("Fitting k-nearest-neighbour model on training images 1...")
knn = NearestNeighbors(n_neighbors=2, metric="cosine")
knn.fit(E_train_flatten)
# Out:
# Fitting k-nearest-neighbour model on training images 1...
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='cosine',
#                  metric_params=None, n_jobs=None, n_neighbors=2, p=2,
#                  radius=1.0)

# %%
print("Image retrieval on test images...")
for i, emb_flatten in enumerate(E_test_flatten):
    _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
    img_query = imgs_test[i] # query image
    imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
    outFile = os.path.join(outDir, "{}_retrieval_{}.png".format(modelName, i))
    plot_query_retrieval(img_query, imgs_retrieval, outFile)
# Out:
# Image retrieval on test images...

# %%
print("Visualizing t-SNE on training images...")
outFile = os.path.join(outDir, "{}_tsne.png".format(modelName))
plot_tsne(E_train_flatten, imgs_train, outFile)
# Out:
# Visualizing t-SNE on training images...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img_path="/content/drive/My Drive/Machine Learning/Output images/convAE_retrieval_0.png"
img = mpimg.imread(img_path)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img_path="/content/drive/My Drive/Machine Learning/Output images/convAE_retrieval_1.png"
img = mpimg.imread(img_path)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img_path="/content/drive/My Drive/Machine Learning/Output images/convAE_retrieval_2.png"
img = mpimg.imread(img_path)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img_path="/content/drive/My Drive/Machine Learning/Output images/convAE_reconstruct.png"
img = mpimg.imread(img_path)
plt.imshow(img)
